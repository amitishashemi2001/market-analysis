# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/amitishashemi/Downloads/Market.csv')

# %%
df = pd.DataFrame(data)
df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
#چون فقط ایندکس های ان-وای-ای مدنظر ما هستند ، پس فقط آنهارا انتخاب میکنیم و در دیتافریم جدید قرار میدهیم 
df1 = df[df["Index"]=="NYA"]
df1
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
#ستون والیوم را حذف میکنیم چون مقادیر زیاذی ۰ رد شدن

# %%
df2 = df1.drop(columns = "Volume")
df2
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close
# 0        528.690002    528.690002
# 1        527.210022    527.210022
# 2        527.840027    527.840027
# ...

# %%
#اعداد اعشار را به اینتیجر تغییر میدهیم

# %%
df3 = round(df2)
df3
# Out:
#       Index        Date     Open     High      Low    Close  Adj Close
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13948 rows x 7 columns]

# %%
#باید تاریخ را حتما سورت کنیم

# %%
df3.sort_values (by = ["Date"])
df3
# Out:
#       Index        Date     Open     High      Low    Close  Adj Close
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13948 rows x 7 columns]

# %%
#میسینگ ولیو ها را دراپ میکنیم 
df4 =df3.dropna()
df4
# Out:
#       Index        Date     Open     High      Low    Close  Adj Close
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13932 rows x 7 columns]

# %%
plt.scatter(df4['Open'] , df4['Adj Close'])
plt.xlabel("Open")
plt.xticks(rotation = 90)
plt.ylabel("Adj Close")
plt.show()

# %%
#باید نویزهای ایجاد شده را حذف کنیم 
Noise = df4[(df4["Adj Close"] > 5000) & (df4["Open"] < 2000 )]
Noise
# Out:
#     Index       Date   Open   High    Low  Close  Adj Close
# 831   NYA  5/29/1969  612.0  612.0  612.0  612.0     6111.0

# %%
Noise1 = df4[(df4["Adj Close"] < 2000) & (df4["Open"] > 5000)]
Noise1
# Out:
#     Index       Date    Open   High    Low  Close  Adj Close
# 852   NYA  6/30/1969  5722.0  572.0  572.0  572.0      572.0

# %%
#نویز پیدا شده را دروپ میکنیم 
df4.drop(index = [831,852], inplace = True)
df4
# Out:
# /var/folders/3f/9ykzv49x4mn1z_mgr9zm7kwm0000gn/T/ipykernel_2000/4292958226.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.drop(index = [831,852], inplace = True)
#       Index        Date     Open     High      Low    Close  Adj Close
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# ...

# %%
# حال اگر یکبار دیگر اسکترپلات بالا را ، ران کنیم میبینیم که دوتا نویز حذف شده اند

# %%
plt.scatter(df4['High'] , df4['Adj Close'])
plt.xlabel("High")
plt.xticks(rotation = 90)
plt.ylabel("Adj Close")
plt.show()

# %%
Noise3 = df4[(df4["Adj Close"] < 2000 ) & (df4["High"] > 5000 )]
Noise3
# Out:
#     Index       Date   Open    High    Low  Close  Adj Close
# 829   NYA  5/27/1969  612.0  6124.0  612.0  612.0      612.0
# 833   NYA   6/3/1969  607.0  6066.0  607.0  607.0      607.0

# %%
df4.drop(index = [829,833] , inplace = True)
df4
# Out:
# /var/folders/3f/9ykzv49x4mn1z_mgr9zm7kwm0000gn/T/ipykernel_2000/3637208478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.drop(index = [829,833] , inplace = True)
#       Index        Date     Open     High      Low    Close  Adj Close
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# ...

# %%
plt.scatter(df4['Low'] , df4['Adj Close'])
plt.xlabel("Low")
plt.xticks(rotation = 90)
plt.ylabel("Adj Close")
plt.show()

# %%
# تنظیم اندازه پلات
fig, ax = plt.subplots(figsize=(13, 10))
ax.scatter(df4['Date'], df4['Adj Close'])
ax.set_xlabel("Date")
ax.set_ylabel("Adj Close")
plt.xticks(rotation=90)
plt.show()

# %%
df4['Date'] = pd.to_datetime(df4['Date'])

df4['year'] = df4.Date.apply(lambda x: x.to_pydatetime().year)
temp = df4.groupby('year').agg(np.mean).reset_index()
# Out:
# /var/folders/3f/9ykzv49x4mn1z_mgr9zm7kwm0000gn/T/ipykernel_2000/3656637917.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Date'] = pd.to_datetime(df4['Date'])
# /var/folders/3f/9ykzv49x4mn1z_mgr9zm7kwm0000gn/T/ipykernel_2000/3656637917.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['year'] = df4.Date.apply(lambda x: x.to_pydatetime().year)

# %%
# تنظیم اندازه پلات
fig, ax = plt.subplots(figsize=(13, 10))
ax.scatter(df4['Date'], df4[Open'])
ax.set_xlabel("Date")
ax.set_ylabel("Open")
plt.xticks(rotation=90)
plt.show()
# Out:
#   File "/var/folders/3f/9ykzv49x4mn1z_mgr9zm7kwm0000gn/T/ipykernel_2000/784560459.py", line 3
#     ax.scatter(df4['Date'], df4[Open'])
#                                        ^
# SyntaxError: EOL while scanning string literal

# %%
# تنظیم اندازه پلات
fig, ax = plt.subplots(figsize=(13, 10))
ax.scatter(df4['Date'], df4['Close'])
ax.set_xlabel("Close")
plt.xticks(rotation=90)
plt.show()

# %%
# تنظیم اندازه پلات
fig, ax = plt.subplots(figsize=(13, 10))
ax.scatter(df4['Date'], df4['Low'])
ax.set_xlabel("Date")
ax.set_ylabel("Low")
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
# تنظیم اندازه پلات
fig, ax = plt.subplots(figsize=(13, 10))
ax.scatter(df4['Date'], df4['High'])
ax.set_xlabel("Date")
ax.set_ylabel("High")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
temp
# Out:
#     year          Open          High           Low         Close     Adj Close
# 0   1965    529.000000    529.000000    529.000000    529.000000    529.000000
# 1   1966    488.056911    488.056911    488.056911    488.056911    488.056911
# 2   1967    537.549180    537.549180    537.549180    537.549180    537.549180
# 3   1968    583.129464    583.129464    583.129464    583.129464    583.129464
# 4   1969    577.102041    577.114286    577.102041    577.102041    577.102041
# 5   1970    483.062992    483.062992    483.062992    483.062992    483.062992
# 6   1971    573.549407    573.549407    573.549407    573.549407    573.549407
# 7   1972    637.191235    637.191235    637.191235    637.191235    637.191235
# 8   1973    607.126984    607.126984    607.126984    607.126984    607.126984
# 9   1974    463.142292    463.142292    463.142292    463.142292    463.142292
# 10  1975    483.675889    483.675889    483.675889    483.675889    483.675889
# ...

# %%
df4.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  13928.000000  13928.000000  13928.000000  13928.000000  13928.000000
# mean    4457.119687   4473.604322   4439.012995   4457.518883   4457.518883
# std     4075.157701   4095.381377   4053.002247   4075.666761   4075.666761
# min      348.000000    348.000000    348.000000    348.000000    348.000000
# 25%      656.000000    656.000000    656.000000    656.000000    656.000000
# 50%     2634.000000   2634.000000   2634.000000   2634.000000   2634.000000
# 75%     7350.250000   7385.250000   7282.750000   7348.500000   7348.500000
# max    16590.000000  16686.000000  16532.000000  16590.000000  16590.000000
#
#                year
# count  13928.000000
# mean    1993.271180
# std       15.948931
# min     1965.000000
# 25%     1979.000000
# 50%     1993.000000
# 75%     2007.000000
# max     2021.000000
